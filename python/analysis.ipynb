# %%
 n = [50,100,300,500,700,900,1100]
 d = [1,4,14,25,37,48,60]
import numpy as np
import matplotlib.pyplot as plt

 a,b = np.polyfit(n,d,1)
 plt.figure()
 plt.grid()
 plt.plot(n,d)
 plt.xlabel('N incr')
 plt.ylabel('deg')
 plt.show()
 print("le coef de reg est "+str(round(a,3))+" incr/deg")
# Out:
# le coef de reg est 0.056 incr/deg
